# %% [markdown]
# # 在Notebook中使用Bokeh绘制图表

# %% [markdown]
# Bokeh是Continuum Analytics开发的一套基于Python和Javascript的绘图库。它可以在Notebook中使用，官方推荐的方式是：
#
# ```python
# from bokeh.io import output_notebook
# output_notebook()
# ```
#
# 它缺省从CDN载入Javascript和CSS库。但是在没有网络连接的环境中无法使用Bokeh。这时可以使用:
#
# ```python
# from bokeh.resources import INLINE
# output_notebook(INLINE)
# ```
#
# 使用`INLINE`将所有的Javascript和CSS库嵌入到Notebook之中，虽然它可以离线使用，但是会增大Notebook体积。这里介绍一种新的方法。
#
# 首先调用`copy_bokeh_resources()`将资源文件复制到`static`文件夹之下：

# %%
def copy_bokeh_resources():
    import os
    import shutil
    from os import path
    from bokeh.resources import INLINE

    for folder in ["static/js", "static/css"]:
        if not path.exists(folder):
            os.makedirs(folder)

    for fn in INLINE._file_paths("js"):
        shutil.copy(fn, "static/js")
    for fn in INLINE._file_paths("css"):
        shutil.copy(fn, "static/css")

# %%
copy_bokeh_resources()

# %% [markdown]
# 然后使用`Resource`对象指定资源载入的方式和URL：

# %%
from bokeh.io import output_notebook
from bokeh.resources import Resources

output_notebook(Resources(mode="server", root_url="./"))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9b026d84-2f7f-4b74-866c-357c260df54d">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure
from bokeh.io import show
import numpy as np

x = np.linspace(0, 4*np.pi, 500)
y = np.sin(x)

fig = figure(height=300)
fig.line(x, y)
show(fig);
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="335f5052-6151-425f-99fd-4182d8435b80"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("335f5052-6151-425f-99fd-4182d8435b80");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '335f5052-6151-425f-99fd-4182d8435b80' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"27132374-1660-4be2-afa1-908103367e45":{"roots":{"references":[{"attributes":{"formatter":{"id":"c30d2bab-bb70-4ac5-ad6f-773c10da8d64","type":"BasicTickFormatter"},"plot":{"id":"27d3d12a-7b5e-4ea6-9b49-9a04f526590f","subtype":"Figure","type":"Plot"},"ticker":{"id":"249ffd6e-3f28-4eb5-a622-91ae3d01df2e","type":"BasicTicker"}},"id":"0b005fc7-c422-4a6f-9615-006c6360ecdb","type":"LinearAxis"},{"attributes":{},"id":"1ab44c30-e5cf-4477-92d8-08992b244234","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"11bf2e3c-1d08-4227-971c-196386a94a7a","type":"ColumnDataSource"},"glyph":{"id":"e56e7f61-ab97-49fb-8c85-0492cac498b5","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"89dd1290-cef5-4a14-9130-45d49f2989dd","type":"Line"},"selection_glyph":null},"id":"0310fc11-f6fa-497d-b1ff-bd752235aa1d","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"10901883-f941-4338-b25d-a667c324a2ae","type":"Title"},{"attributes":{},"id":"5e8cb36e-f3bd-4030-9624-8b79c3a7a737","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d818fee6-e3e7-4808-9b97-21805370c248","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"89dd1290-cef5-4a14-9130-45d49f2989dd","type":"Line"},{"attributes":{"plot":{"id":"27d3d12a-7b5e-4ea6-9b49-9a04f526590f","subtype":"Figure","type":"Plot"}},"id":"ce43baae-6954-4c3b-8654-4a0d17953e6f","type":"ResetTool"},{"attributes":{"formatter":{"id":"1ab44c30-e5cf-4477-92d8-08992b244234","type":"BasicTickFormatter"},"plot":{"id":"27d3d12a-7b5e-4ea6-9b49-9a04f526590f","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e8cb36e-f3bd-4030-9624-8b79c3a7a737","type":"BasicTicker"}},"id":"e4cd1aac-8d86-405a-b9a3-11785b5b3bf0","type":"LinearAxis"},{"attributes":{"callback":null},"id":"e03f85a6-c92a-46cc-ab6d-4fd17fcd6ef4","type":"DataRange1d"},{"attributes":{},"id":"dd6a607e-73c7-47b1-971f-cc9017be5740","type":"ToolEvents"},{"attributes":{"plot":{"id":"27d3d12a-7b5e-4ea6-9b49-9a04f526590f","subtype":"Figure","type":"Plot"}},"id":"37230bc9-153e-4b7f-959a-c28fed930a68","type":"PanTool"},{"attributes":{"below":[{"id":"e4cd1aac-8d86-405a-b9a3-11785b5b3bf0","type":"LinearAxis"}],"left":[{"id":"0b005fc7-c422-4a6f-9615-006c6360ecdb","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"e4cd1aac-8d86-405a-b9a3-11785b5b3bf0","type":"LinearAxis"},{"id":"08dd2e9a-eef2-4852-b1be-74c79e88e459","type":"Grid"},{"id":"0b005fc7-c422-4a6f-9615-006c6360ecdb","type":"LinearAxis"},{"id":"6dbe871e-bb23-433b-bbca-d7822c60360c","type":"Grid"},{"id":"d818fee6-e3e7-4808-9b97-21805370c248","type":"BoxAnnotation"},{"id":"0310fc11-f6fa-497d-b1ff-bd752235aa1d","type":"GlyphRenderer"}],"title":{"id":"10901883-f941-4338-b25d-a667c324a2ae","type":"Title"},"tool_events":{"id":"dd6a607e-73c7-47b1-971f-cc9017be5740","type":"ToolEvents"},"toolbar":{"id":"3e3d488f-a01e-47a6-bd4f-a378c7e14053","type":"Toolbar"},"x_range":{"id":"95eab539-7db3-4309-88b3-a003bb068def","type":"DataRange1d"},"y_range":{"id":"e03f85a6-c92a-46cc-ab6d-4fd17fcd6ef4","type":"DataRange1d"}},"id":"27d3d12a-7b5e-4ea6-9b49-9a04f526590f","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c30d2bab-bb70-4ac5-ad6f-773c10da8d64","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.025183107443605555,0.05036621488721111,0.07554932233081667,0.10073242977442222,0.12591553721802778,0.15109864466163334,0.1762817521052389,0.20146485954884444,0.22664796699245,0.25183107443605557,0.2770141818796611,0.30219728932326667,0.3273803967668722,0.3525635042104778,0.3777466116540833,0.4029297190976889,0.42811282654129446,0.45329593 ...

# %% [markdown]
# 在Bokeh 0.12中，创建的所有`Figure`对象会被累积到当前文档中。例如运行上述程序多次之后，会发现当前文档中包含多个`Figure`对象。这个BUG会导致程序运行越来越慢，内存越占越多。

# %%
from bokeh.plotting import curdoc
doc = curdoc()
doc.roots
# Out:
# [<bokeh.plotting.figure.Figure at 0x7f8a6d42d940>,
#  <bokeh.plotting.figure.Figure at 0x7f8a6d3e67b8>,
#  <bokeh.plotting.figure.Figure at 0x7f8a6d3e6470>,
#  <bokeh.plotting.figure.Figure at 0x7f8a6d38a518>]

# %% [markdown]
# 为了解决上述问题，可以在每次调用`show()`显示图表之前，用`curdoc().clear()`清空当前文档。

# %%
curdoc().clear()
doc.roots
# Out:
# []

# %% [markdown]
# Bokeh绘制的图表在Python和Javascript分别有对应的对象。在Python修改图表中对象的属性之后，调用`push_notebook()`将修改信息发送给Javascript刷新图表中的显示。下面使用`line`变量保存`fig.line()`的返回对象，然后调用`show()`显示一副图表：

# %%
fig = figure(height=300)
line = fig.line(x, y)
show(fig);
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="092c6fe1-8548-464d-b3e9-7a1a22946a6d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("092c6fe1-8548-464d-b3e9-7a1a22946a6d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '092c6fe1-8548-464d-b3e9-7a1a22946a6d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ca960c20-0227-4e0b-a200-60d283c498eb":{"roots":{"references":[{"attributes":{},"id":"4341973d-d279-4dab-bdb2-c8970e3d5a75","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5
.072339108119878,3.097522215563483,3.122705323007089,3.147888430450694,3.1730715378943,3.1982546453379053,3.223437752781511,3.2486208602251168,3.273803967668722,3.298987075112328,3.324170182555933,3.349353289999539,3.374536397443144,3.39971950488675,3.4249026123303556,3.450085719773961,3.4752688272175667,3.500451934661172,3.5256350421047777,3.550818149548383,3.576001256991989,3.6011843644355945,3.6263674718792,3.6515505793228056,3.676733686766411,3.7019167942100166,3.727099901653622,3.7522830090972277,3.7774661165408334,3.8026492239844387,3.8278323314280445,3.8530154388716498,3.8781985463152555,3.903381653758861,3.9285647612024666,3.9537478686460723,3.9789309760896776,4.004114083533283,4.029297190976889,4.054480298420494,4.0796634058641,4.104846513307705,4.130029620751311,4.1552127281949165,4.180395835638522,4.205578943082128,4.230762050525733,4.255945157969339,4.281128265412944,4.30631137285655,4.331494480300155,4.356677587743761,4.381860695187367,4.407043802630972,4.4322269100745775,4.457410017518183,4.482593124961789,4.507776232405394,4.532959339849,4.558142447292606,4.583325554736211,4.608508662179816,4.633691769623422,4.658874877067028,4.684 ...

# %% [markdown]
# 下面调用通过设置`line1.data_source.data["y"]`修改曲线的Y轴数据。通过`line2.glyph.line_color`修改曲线的颜色，然后调用`update_figure()`更新图表。

# %%
line1.data_source.data["y"] = np.sin(x) / x
line2.glyph.line_color = "red"
update_figure(fig1)
update_figure(fig2)

# %% [markdown]
# ## 用ipywidgets制作图表控制面板

# %% [markdown]
# 我们可以使用ipywidgets库创建控制图表的控件，在控件的事件响应函数中修改图表的各个对象的属性，然后调用`update_figure()`更新图表。下面是一个例子。
#
# 程序中，为了方便更新曲线数据，❶先创建一个`ColumnDataSource`对象，❷在调用`fig.line()`时，使用`source`参数指定曲线的数据源为该对象。使用这种方法绘制曲线时，`line()`的头两个参数为X轴和Y轴数据在`ColumnDataSource`对象中对应的键。
#
# ❸为滑块控件`freq_slider`绑定回调函数`callback`，当滑块的`value`属性值被修改时，会调用`callback`函数。其参数`event`中保存与时间相关的信息，`event["new"]`为滑块的新位置。

# %%
from ipywidgets import FloatSlider
from IPython.display import display
from bokeh.models import ColumnDataSource

fig = Figure(plot_height=300)
data = ColumnDataSource(data=dict(x=[], y=[]), id="data") #❶
fig.line("x", "y", source=data, line_width=2)  #❷

def update_source(source, freq):
    x = np.linspace(0, 2, 100)
    y = np.sin(2*np.pi*freq*x)
    source.data["x"] = x
    source.data["y"] = y

def callback(event):
    freq = event["new"]
    update_source(data, freq)
    update_figure(fig)

freq_slider = FloatSlider(value=0, min=0, max=3, description="Freq:")
freq_slider.observe(callback, names=["value"])  #❸
display(freq_slider)
show_figure(fig)
freq_slider.value = 1.0
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f2ac686c-aaf9-46fd-ac5e-1848294d4376"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2ac686c-aaf9-46fd-ac5e-1848294d4376");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2ac686c-aaf9-46fd-ac5e-1848294d4376' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"99db8d75-19b9-46bd-a66c-abd16a45a634":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[],"y":[]}},"id":"data","type":"ColumnDataSource"},{"attributes":{},"id":"a9b82be1-e8ff-4d50-bf47-87b147cd5ce2","type":"BasicTicker"},{"attributes":{"below":[{"id":"c1f54c39-6fad-4a95-bc96-3f32ee3c5cc4","type":"LinearAxis"}],"left":[{"id":"cfcef072-3297-4158-b769-8f191aa97eee","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"c1f54c39-6fad-4a95-bc96-3f32ee3c5cc4","type":"LinearAxis"},{"id":"7e652f02-8718-412c-b63d-ab87ddd7eb8c","type":"Grid"},{"id":"cfcef072-3297-4158-b769-8f191aa97eee","type":"LinearAxis"},{"id":"baeb319a-a1d6-4013-bbd8-1c919553da48","type":"Grid"},{"id":"7d503052-d868-4af4-a823-9b72d8ecc59a","type":"BoxAnnotation"},{"id":"a5eb6616-8d04-44db-b5cb-fbf0ca2accb0","type":"GlyphRenderer"}],"title":{"id":"4a2d6aa2-d8fc-4d37-a26d-bdfae7e2a5bb","type":"Title"},"tool_events":{"id":"9c36eb1d-02ee-4695-be4b-59d9c2eaba7c","type":"ToolEvents"},"toolbar":{"id":"1fffc674-0748-4733-aaf7-6c956c417a99","type":"Toolbar"},"x_range":{"id":"47ea0c49-3bbc-4ea2-ad58-3fcb688a298a","type":"DataRange1d"},"y_range":{"id":"49d6bc4d-b27a-40ff-aedf-0f714e647cf2","type":"DataRange1d"}},"id":"b330623f-7823-46cb-8060-f40446df07b3","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"49d6bc4d-b27a-40ff-aedf-0f714e647cf2","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8368b183-6010-4313-871c-e4f91a18954c","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7d503052-d868-4af4-a823-9b72d8ecc59a","type":"BoxAnnotation"},{"attributes":{},"id":"c4527629-43b7-4866-af65-42026325126d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b330623f-7823-46cb-8060-f40446df07b3","subtype":"Figure","type":"Plot"}},"id":"8c86091a-0137-486c-a85d-8737476b9ec5","type":"WheelZoomTool"},{"attributes":{},"id":"e3931f79-f9ea-4cfb-ac64-3c7c2ade7591","type":"BasicTicker"},{"attributes":{},"id":"9c36eb1d-02ee-4695-be4b-59d9c2eaba7c","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a0e849ae-6ddd-4c07-9662-996b64c34058","type":"PanTool"},{"id":"8c86091a-0137-486c-a85d-8737476b9ec5","type":"WheelZoomTool"},{"id":"c6219740-3b4e-4851-8d8c-8fa796862d6d","type":"BoxZoomTool"},{"id":"b97daef0-1faf-4b36-ba20-c371e5bb976a","type":"SaveTool"},{"id":"e7f14afe-1408-4a6e-b6a7-aebf21d1a217","type":"ResetTool"},{"id":"fd7d4431-f08c-4f79-96d9-a51700803dcd","type":"HelpTool"}]},"id":"1fffc674-0748-4733-aaf7-6c956c417a99","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"6016aaee-3544-4ce8-a463-3b798f73a56b","type":"Line"},{"attributes":{"plot":{"id":"b330623f-7823-46cb-8060-f40446df07b3","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9b82be1-e8ff-4d50-bf47-87b147cd5ce2","type":"BasicTicker"}},"id":"7e652f02-8718-412c-b63d-ab87ddd7eb8c","type":"Grid"},{"attributes":{"callback":null},"id":"47ea0c49-3bbc-4ea2-ad58-3fcb688a298a","type":"DataRange1d"},{"attributes":{"plot":{"id":"b330623f-7823-46cb-8060-f40446df07b3","subtype":"Figure","type":"Plot"}},"id":"e7f14afe-1408-4a6e-b6a7-aebf21d1a217","type":"ResetTool"},{"attributes":{"formatter":{"id":"b31f7f2b-aaec-4190-9a11-c08dd7fa557a","type":"BasicTickFormatter"},"plot":{"id":"b330623f-7823-46cb-8060-f40446df07b3","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9b82be1-e8ff-4d50-bf47-87b147cd5ce2","type":"BasicTicker"}},"id":"c1f54c39-6fad-4a95-bc96-3f32ee3c5cc4","type":"LinearAxis"},{"attributes": ...
