# %% [markdown]
# # 在Notebook中使用Bokeh绘制图表

# %% [markdown]
# Bokeh是Continuum Analytics开发的一套基于Python和Javascript的绘图库。它可以在Notebook中使用，官方推荐的方式是：
#
# ```python
# from bokeh.io import output_notebook
# output_notebook()
# ```
#
# 它缺省从CDN载入Javascript和CSS库。但是在没有网络连接的环境中无法使用Bokeh。这时可以使用:
#
# ```python
# from bokeh.resources import INLINE
# output_notebook(INLINE)
# ```
#
# 使用`INLINE`将所有的Javascript和CSS库嵌入到Notebook之中，虽然它可以离线使用，但是会增大Notebook体积。这里介绍一种新的方法。
#
# 首先调用`copy_bokeh_resources()`将资源文件复制到`static`文件夹之下：

# %%
def copy_bokeh_resources():
    import os
    import shutil
    from os import path
    from bokeh.resources import INLINE

    for folder in ["static/js", "static/css"]:
        if not path.exists(folder):
            os.makedirs(folder)

    for fn in INLINE._file_paths("js"):
        shutil.copy(fn, "static/js")
    for fn in INLINE._file_paths("css"):
        shutil.copy(fn, "static/css")

# %% [markdown]
# 然后使用`Resource`对象指定资源载入的方式和URL：

# %%
from bokeh.io import output_notebook
from bokeh.resources import Resources

output_notebook(Resources(mode="server", root_url="./"))
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="57067160-743a-4aa1-bf68-a9586eaf70ac">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure
from bokeh.io import show
import numpy as np

x = np.linspace(0, 4*np.pi, 500)
y = np.sin(x)

fig = figure(height=300)
fig.line(x, y)
show(fig);
# Out:
#     <div class="plotdiv" id="536c0bbb-3158-48dd-a848-0c82e9bc50ec"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("536c0bbb-3158-48dd-a848-0c82e9bc50ec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '536c0bbb-3158-48dd-a848-0c82e9bc50ec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ab2f5f24-034b-4d6d-b3e3-15e70a248f52":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"da923896-cd79-4dfa-a576-aec90a3b6228","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.025183107443605555,0.05036621488721111,0.07554932233081667,0.10073242977442222,0.12591553721802778,0.15109864466163334,0.1762817521052389,0.20146485954884444,0.22664796699245,0.25183107443605557,0.2770141818796611,0.30219728932326667,0.3273803967668722,0.3525635042104778,0.3777466116540833,0.4029297190976889,0.42811282654129446,0.4532959339849,0.47847904142850556,0.5036621488721111,0.5288452563157167,0.5540283637593222,0.5792114712029277,0.6043945786465333,0.6295776860901389,0.6547607935337444,0.67994390097735,0.7051270084209555,0.7303101158645611,0.7554932233081666,0.7806763307517722,0.8058594381953778,0.8310425456389833,0.8562256530825889,0.8814087605261944,0.9065918679698,0.9317749754134055,0.9569580828570111,0.9821411903006166,1.0073242977442223,1.0325074051878278,1.0576905126314333,1.0828736200750388,1.1080567275186444,1.13323983496225,1.1584229424058554,1.1836060498494612,1.2087891572930667,1.2339722647366722,1.2591553721802777,1.2843384796238833,1.3095215870674888,1.3347046945110943,1.3598878019547,1.3850709093983056,1.410254016841911,1.4354371242855166,1.4606202317291221,1.4858033391727277,1.5109864466163332,1.536169554059939,1.5613526615035445,1.58653576894715,1.6117188763907555,1.636901983834361,1.6620850912779666,1.687268198721572,1.7124513061651778,1.7376344136087833,1.7628175210523889,1.7880006284959944,1.8131837359396,1.8383668433832054,1.863549950826811,1.8887330582704167,1.9139161657140222,1.9390992731576278,1.9642823806012333,1.9894654880448388,2.0146485954884445,2.03983170293205,2.0650148103756556,2.090197917819261,2.1153810252628666,2.140564132706472,2.1657472401500777,2.1909303475936834,2.2161134550372887,2.2412965624808945,2.2664796699245,2.2916627773681055,2.316845884811711,2.3420289922553166,2.3672120996989223,2.3923952071425276,2.4175783145861334,2.4427614220297387,2.4679445294733444,2.4931276369169497,2.5183107443605555,2.543493851804161,2.5686769592477665,2.5938600666913723,2.6190431741349776,2.6442262815785833,2.6694093890221886,2.6945924964657944,2.7197756039094,2.7449587113530054,2.770141818796611,2.7953249262402164,2.820508033683822,2.8456911411274275,2.8708742485710332,2.896057356014639,2.9212404634582443,2.94642357090185,2.9716066783454553,2.996789785789061,3.0219728932326664,3.047156000676272,3.072339108119878,3.097522215563483,3.122705323007089,3.147888430450694,3.1730715378943,3.1982546453379053,3.223437752781511,3.2486208602251168,3.273803967668722,3.298987075112328,3.324170182555933,3.349353289999539,3.374536397443144,3.39971950488675,3.4249026123303556,3.450085719773961,3.4752688272175667,3.500451934661172,3.5256350421047777,3.550818149548383,3.576001256991989,3.6011843644355945,3.6263674718792,3.6515505793228056,3.676733686766411,3.7019167942100166,3.727099901653622,3.7522830090972277,3.7774661165408334,3.8026492239844387,3.8278323314280445,3.8530154388716498,3.8781985463152555,3.903381653758861,3.9285647612024666,3.9537478686460723,3.9789309760896776,4.004114083533283,4.029297190976889,4.054480298420494,4.0796634058641,4.104846513307705,4.130029620751311,4.1552127281949165,4.180395835638522,4.205578943082128,4.230762050525733,4.255945157969339,4.281128265412944,4.30631137285655,4.331494480300155,4.356677587743761,4.381860695187367,4.407043802630972,4.4322269100745775,4.457410017518183,4.482593124961789,4.507776232405394,4.532959339849,4.558142447292606,4.583325554736211,4.608508662179816,4.633691769623422,4.658874877067028,4.684057984510633,4.7092410919542385,4.734424199397845,4.75960730684145,4.784790414285055,4.8099735217286606,4.835156629172267,4.860339736615872,4.885522844059477,4.9107059515030835,4.935889058946689,4.961072166390294,4.986255273833899,5.011438381277506,5.03662148 ...

# %% [markdown]
# 在Bokeh 0.11中，创建的所有`Figure`对象会被累积到当前文档中。例如运行上述程序多次之后，会发现当前文档中包含多个`Figure`对象。这个BUG会导致程序运行越来越慢，内存越占越多。

# %%
from bokeh.plotting import curdoc
doc = curdoc()
doc.roots
# Out:
# [<bokeh.plotting.figure.Figure at 0x7f012c620828>,
#  <bokeh.plotting.figure.Figure at 0x7f012c5ccc88>]

# %% [markdown]
# 为了解决上述问题，可以在每次调用`show()`显示图表之前，用`curdoc().clear()`清空当前文档。

# %%
curdoc().clear()
doc.roots
# Out:
# []

# %% [markdown]
# Bokeh绘制的图表在Python和Javascript分别有对应的对象。在Python修改图表中对象的属性之后，调用`push_notebook()`将修改信息发送给Javascript刷新图表中的显示。下面使用`line`变量保存`fig.line()`的返回对象，然后调用`show()`显示一副图表：

# %%
fig = figure(height=300)
line = fig.line(x, y)
show(fig);
# Out:
#     <div class="plotdiv" id="1bc96cbb-ebb3-4aa8-9bba-eaab169a2f4e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1bc96cbb-ebb3-4aa8-9bba-eaab169a2f4e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1bc96cbb-ebb3-4aa8-9bba-eaab169a2f4e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"904d2ea5-4178-425e-bfb2-75699f2b1ec0":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"5def996d-47a6-4b8b-af60-9e7ae6a4a335","subtype":"Figure","type":"Plot"},"ticker":{"id":"76965ad0-96d5-4b50-9e03-c8c5802f01b5","type":"BasicTicker"}},"id":"4d1c1ca1-7d8d-49f7-bd5b-57daba13987b","type":"Grid"},{"attributes":{"callback":null},"id":"42978a86-89f1-4806-ba07-91bc37f5fbe0","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":
# %% [markdown]
# 下面修改`line.glyph.line_width`属性，它表示曲线的宽度，然后调用`push_notebook()`刷新图表显示：

# %%
from bokeh.io import push_notebook
line.glyph.line_width = 2
push_notebook()

# %%
curdoc().clear()

# %% [markdown]
# ## 使用`push_notebook()`刷新多幅图表

# %% [markdown]
# 使用前面所述的方法，只能更新最后显示的图表，本节介绍刷新多幅图表的方法。
#
# 调用`figure()`创建图表时，会创建相应的`Document`对象，而`push_notebook()`则将该`Document`对象中被修改的内容发送到Javascript刷新显示。如果直接创建`Figure()`对象，则不会创建相应的`Document`对象。

# %%
from bokeh.plotting import Figure
from bokeh.document import Document
from bokeh.io import curstate

def show_figure(fig):
    if fig.document is None:
        doc = Document()
        doc.add_root(fig)
        curstate().document = doc
    fig.__dict__["_handle"] = show(fig)
    
def update_figure(fig):
    push_notebook(fig.document, None, fig._handle)

# %%
fig1 = Figure(plot_height=300)
line1 = fig1.line(x, y)
show_figure(fig1);
# Out:
#     <div class="plotdiv" id="4a24b5b9-5748-4ef8-8b43-e075408a97b2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a24b5b9-5748-4ef8-8b43-e075408a97b2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a24b5b9-5748-4ef8-8b43-e075408a97b2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"24c39411-4369-492a-b057-10dc2829102b":{"roots":{"references":[{"attributes":{},"id":"8daee018-7c6a-4666-a666-6c4826672e05","type":"BasicTickFormatter"},{"attributes":{},"id":"42dd18c2-e73a-424a-8d2a-0983c668eac0","type":"ToolEvents"},{"attributes":{"callback":null},"id":"69048728-705a-47c7-92fc-aa8c0b69553a","type":"DataRange1d"},{"attributes":{},"id":"d4fbc259-cee3-488b-9a06-c88fe8862d6e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"cbc0a7f6-50e8-445a-92d3-2c09c3be747f","subtype":"Figure","type":"Plot"}},"id":"769a0b7b-db7e-4d4e-9532-49bf28188564","type":"PanTool"},{"attributes":{"data_source":{"id":"acaa5b0a-9a79-48c0-94ce-c5a9ea24bd07","type":"ColumnDataSource"},"glyph":{"id":"08e9222c-9b29-4f15-b079-b7e4c41c2b6f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4c75f50f-45e8-45fd-a415-9df79dc860d7","type":"Line"},"selection_glyph":null},"id":"09d5b182-ddce-4c8c-b85e-17966ede24eb","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.025183107443605555,0.05036621488721111,0.07554932233081667,0.10073242977442222,0.12591553721802778,0.15109864466163334,0.1762817521052389,0.20146485954884444,0.22664796699245,0.25183107443605557,0.2770141818796611,0.30219728932326667,0.3273803967668722,0.3525635042104778,0.3777466116540833,0.4029297190976889,0.42811282654129446,0.4532959339849,0.47847904142850556,0.5036621488721111,0.5288452563157167,0.5540283637593222,0.5792114712029277,0.6043945786465333,0.6295776860901389,0.6547607935337444,0.67994390097735,0.7051270084209555,0.7303101158645611,0.7554932233081666,0.7806763307517722,0.8058594381953778,0.8310425456389833,0.8562256530825889,0.8814087605261944,0.9065918679698,0.9317749754134055,0.9569580828570111,0.9821411903006166,1.0073242977442223,1.0325074051878278,1.0576905126314333,1.0828736200750388,1.1080567275186444,1.13323983496225,1.1584229424058554,1.1836060498494612,1.2087891572930667,1.2339722647366722,1.2591553721802777,1.2843384796238833,1.3095215870674888,1.3347046945110943,1.3598878019547,1.3850709093983056,1.410254016841911,1.4354371242855166,1.4606202317291221,1.4858033391727277,1.5109864466163332,1.536169554059939,1.5613526615035445,1.58653576894715,1.6117188763907555,1.636
type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"06bd140b-fb4c-4d89-ae29-881fa55fc5a3","type":"Line"},"selection_glyph":null},"id":"3e2a408c-e372-460e-a78b-4d5a66dc5d98","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"06bd140b-fb4c-4d89-ae29-881fa55fc5a3","type":"Line"},{"attributes":{"callback":null},"id":"62924dea-3141-4ade-aac8-725e66c65798","type":"DataRange1d"},{"attributes":{"plot":{"id":"5a149d2e-2b9c-4193-bf0b-ac569c9772e9","subtype":"Figure","type":"Plot"}},"id":"db654e51-658c-40e8-aa44-13fcc6969401","type":"ResetTool"},{"attributes":{},"id":"2c9b0597-6d52-4e48-b370-c4217695503e","type":"BasicTicker"},{"attributes":{"below":[{"id":"725a3c1b-6750-4e3b-b3dd-c9230f0e9e9f","type":"LinearAxis"}],"left":[{"id":"ea7952d1-9968-439d-9d8c-ef7c265370c6","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"725a3c1b-6750-4e3b-b3dd-c9230f0e9e9f","type":"LinearAxis"},{"id":"93c0dbce-8a36-4381-b73f-42e61f9dd145","type":"Grid"},{"id":"ea7952d1-9968-439d-9d8c-ef7c265370c6","type":"LinearAxis"},{"id":"5c89ca6e-fd9c-419f-a793-ac882bbd15d0","type":"Grid"},{"id":"a5036bc8-d559-413b-83ef-167f47878566","type":"BoxAnnotation"},{"id":"3e2a408c-e372-460e-a78b-4d5a66dc5d98","type":"GlyphRenderer"}],"tool_events":{"id":"ec3cf1d3-0d74-4be1-ae46-6e72d338197a","type":"ToolEvents"},"tools":[{"id":"bbaffd04-e07b-4973-9f95-86ccc12c5a4b","type":"PanTool"},{"id":"3fd8a528-9af3-40e2-9ada-21fcafae2317","type":"WheelZoomTool"},{"id":"57f820ee-6820-4a5f-a494-bf26fdad9ae2","type":"BoxZoomTool"},{"id":"844f6c1e-7116-4181-9b8f-3bf5686e011f","type":"PreviewSaveTool"},{"id":"45bd2241-0714-45c0-9d89-720989cc9ceb","type":"ResizeTool"},{"id":"db654e51-658c-40e8-aa44-13fcc6969401","type":"ResetTool"},{"id":"53e8ab74-abc2-468e-8527-de7a40447534","type":"HelpTool"}]," ...

# %% [markdown]
# 下面调用通过设置`line1.data_source.data["y"]`修改曲线的Y轴数据。通过`line2.glyph.line_color`修改曲线的颜色，然后调用`update_figure()`更新图表。

# %%
line1.data_source.data["y"] = np.sin(x) / x
line2.glyph.line_color = "red"
update_figure(fig1)
update_figure(fig2)

# %% [markdown]
# ## 用ipywidgets制作图表控制面板

# %% [markdown]
# 我们可以使用ipywidgets库创建控制图表的控件，在控件的事件响应函数中修改图表的各个对象的属性，然后调用`update_figure()`更新图表。下面是一个例子。
#
# 程序中，为了方便更新曲线数据，❶先创建一个`ColumnDataSource`对象，❷在调用`fig.line()`时，使用`source`参数指定曲线的数据源为该对象。使用这种方法绘制曲线时，`line()`的头两个参数为X轴和Y轴数据在`ColumnDataSource`对象中对应的键。
#
# ❸为滑块控件`freq_slider`绑定回调函数`callback`，当滑块的`value`属性值被修改时，会调用`callback`函数。其参数`event`中保存与时间相关的信息，`event["new"]`为滑块的新位置。

# %%
from ipywidgets import FloatSlider
from IPython.display import display
from bokeh.models import ColumnDataSource

fig = Figure(plot_height=300)
data = ColumnDataSource(data=dict(x=[], y=[]), id="data") #❶
fig.line("x", "y", source=data, line_width=2)  #❷

def update_source(source, freq):
    x = np.linspace(0, 2, 100)
    y = np.sin(2*np.pi*freq*x)
    source.data["x"] = x
    source.data["y"] = y

def callback(event):
    freq = event["new"]
    update_source(data, freq)
    update_figure(fig)

freq_slider = FloatSlider(value=0, min=0, max=3, description="Freq:")
freq_slider.observe(callback, names=["value"])  #❸
display(freq_slider)
show_figure(fig)
freq_slider.value = 1.0
# Out:
#     <div class="plotdiv" id="6c0589b9-bc2f-41e5-aa3d-25971ae4eb97"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6c0589b9-bc2f-41e5-aa3d-25971ae4eb97");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6c0589b9-bc2f-41e5-aa3d-25971ae4eb97' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3353ff73-3b70-4ee4-bfde-65ebd4466e6a":{"roots":{"references":[{"attributes":{},"id":"ad4018fc-abbb-4931-a88d-5054a6839fee","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"d25029e6-fb94-48b4-be51-e94642aa06b5","type":"Line"},{"attributes":{"data_source":{"id":"data","type":"ColumnDataSource"},"glyph":{"id":"7cdf53b2-a010-4b8c-bc95-9c557ce9efaf","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d25029e6-fb94-48b4-be51-e94642aa06b5","type":"Line"},"selection_glyph":null},"id":"8181883f-57f4-41b0-9463-52f6ba7ec172","type":"GlyphRenderer"},{"attributes":{},"id":"5d163595-890b-494b-a4da-f1dd9f33c608","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7cdf53b2-a010-4b8c-bc95-9c557ce9efaf","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"efd02b46-fecc-4d51-82a3-f63f19cf3a4e","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"efd02b46-fecc-4d51-82a3-f63f19cf3a4e","type":"BoxAnnotation"},"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"}},"id":"2a79959c-69e0-4d21-863b-8ebe6890abc8","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[],"y":[]}},"id":"data","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"}},"id":"76872a8e-d442-490c-ae14-499c735d60cd","type":"HelpTool"},{"attributes":{"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"}},"id":"717423b0-ab62-4b45-bb19-11995f6106ca","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"}},"id":"675c3c11-feb9-4c83-95da-ca2ea4845963","type":"ResetTool"},{"attributes":{"callback":null},"id":"d6d254a4-6394-4bfc-ab4a-547623b8fcec","type":"DataRange1d"},{"attributes":{},"id":"53e0bd21-9349-4695-987c-07da39e1f625","type":"BasicTicker"},{"attributes":{"formatter":{"id":"abaca814-c668-4a27-a2cc-3bf69b4d47b2","type":"BasicTickFormatter"},"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad4018fc-abbb-4931-a88d-5054a6839fee","type":"BasicTicker"}},"id":"13ab80f8-ce27-41ba-9a5f-2b72c6a48c3e","type":"LinearAxis"},{"attributes":{"callback":null},"id":"0a520464-bc75-49dc-badb-d3797fa2e080","type":"DataRange1d"},{"attributes":{"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"}},"id":"5332176f-fc7a-47ef-9006-8566edbd3ecf","type":"PanTool"},{"attributes":{},"id":"abaca814-c668-4a27-a2cc-3bf69b4d47b2","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad4018fc-abbb-4931-a88d-5054a6839fee","type":"BasicTicker"}},"id":"a37b14fd-9f5b-425c-ad1b-6c8fc240cc14","type":"Grid"},{"attributes":{"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"}},"id":"85ed01fa-a7fc-41a4-882f-d34680f4d0f8","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"}},"id":"f1c8ed06-dfd0-4b2d-93ee-6ad0d17279c3","type":"ResizeTool"},{"attributes":{"dimension":1,"plot":{"id":"b8129394-3702-4edc-9f52-70987bbf4b70","subtype":"Figure","type":"Plot"},"ticker":{"id":"53e0bd21-9349-4695-987c-07da39e1f625","type":"BasicTicker"}},"id":"1a202092-5bce-41a3-8f88-7b03c8144515","type":"Grid"},{"attributes":{"formatter":{"id":"a02eec7b-e4ed-4308-9170-985d5e15b6df","type":"BasicTickFormatter"},"plot ...
#             var render_items = [{"docid":"3353ff73-3b70-4ee4-bfde-65ebd4466e6a","elementid":"6c0589b9-b
